# %%
from hat.archs import hat_arch
import yaml
import torch

# hat-s 4xsr weights
w = torch.load("./experiments/pretrained_models/HAT-S_SRx4.pth")

# accounting for overlap window change from 0.5 to 0.75
for p in ["params", "params_ema"]:
    del w[p]["relative_position_index_OCA"]
    for k in range(6):
        del w[p][f"layers.{k}.residual_group.overlap_attn.relative_position_bias_table"]

# hat-s 4xsr model options from yml
with open("./options/train/train_HAT-S_SRx4_AST.yml", 'r') as f:
    opts = yaml.safe_load(f)
nopts = opts["network_g"]
del nopts["type"]

model = hat_arch.HAT(**nopts)
model_ema = hat_arch.HAT(**nopts)
print(model.load_state_dict(w["params"], strict=False))
print(model_ema.load_state_dict(w["params_ema"], strict=False))

new_w = {
    "params": model.state_dict(),
    "params_ema": model_ema.state_dict()
}

torch.save(new_w, "./experiments/pretrained_models/HAT-S_SRx4_AST.pth")
# Out:
# _IncompatibleKeys(missing_keys=['relative_position_index_OCA', 'layers.0.residual_group.overlap_attn.ast_weight', 'layers.0.residual_group.overlap_attn.relative_position_bias_table', 'layers.0.residual_group.overlap_attn.frfn.linear1.0.weight', 'layers.0.residual_group.overlap_attn.frfn.linear1.0.bias', 'layers.0.residual_group.overlap_attn.frfn.dwconv.0.weight', 'layers.0.residual_group.overlap_attn.frfn.dwconv.0.bias', 'layers.0.residual_group.overlap_attn.frfn.linear2.0.weight', 'layers.0.residual_group.overlap_attn.frfn.linear2.0.bias', 'layers.0.residual_group.overlap_attn.frfn.partial_conv3.weight', 'layers.1.residual_group.overlap_attn.ast_weight', 'layers.1.residual_group.overlap_attn.relative_position_bias_table', 'layers.1.residual_group.overlap_attn.frfn.linear1.0.weight', 'layers.1.residual_group.overlap_attn.frfn.linear1.0.bias', 'layers.1.residual_group.overlap_attn.frfn.dwconv.0.weight', 'layers.1.residual_group.overlap_attn.frfn.dwconv.0.bias', 'layers.1.residual_group.overlap_attn.frfn.linear2.0.weight', 'layers.1.residual_group.overlap_attn.frfn.linear2.0.bias', 'layers.1.residual_group.overlap_attn.frfn.partial_conv3.weight', 'layers.2.residual_group.overlap_attn.ast_weight', 'layers.2.residual_group.overlap_attn.relative_position_bias_table', 'layers.2.residual_group.overlap_attn.frfn.linear1.0.weight', 'layers.2.residual_group.overlap_attn.frfn.linear1.0.bias', 'layers.2.residual_group.overlap_attn.frfn.dwconv.0.weight', 'layers.2.residual_group.overlap_attn.frfn.dwconv.0.bias', 'layers.2.residual_group.overlap_attn.frfn.linear2.0.weight', 'layers.2.residual_group.overlap_attn.frfn.linear2.0.bias', 'layers.2.residual_group.overlap_attn.frfn.partial_conv3.weight', 'layers.3.residual_group.overlap_attn.ast_weight', 'layers.3.residual_group.overlap_attn.relative_position_bias_table', 'layers.3.residual_group.overlap_attn.frfn.linear1.0.weight', 'layers.3.residual_group.overlap_attn.frfn.linear1.0.bias', 'layers.3.residual_group.overlap_attn.frfn.dwconv.0.weight', 'layers.3.residual_group.overlap_attn.frfn.dwconv.0.bias', 'layers.3.residual_group.overlap_attn.frfn.linear2.0.weight', 'layers.3.residual_group.overlap_attn.frfn.linear2.0.bias', 'layers.3.residual_group.overlap_attn.frfn.partial_conv3.weight', 'layers.4.residual_group.overlap_attn.ast_weight', 'layers.4.residual_group.overlap_attn.relative_position_bias_table', 'layers.4.residual_group.overlap_attn.frfn.linear1.0.weight', 'layers.4.residual_group.overlap_attn.frfn.linear1.0.bias', 'layers.4.residual_group.overlap_attn.frfn.dwconv.0.weight', 'layers.4.residual_group.overlap_attn.frfn.dwconv.0.bias', 'layers.4.residual_group.overlap_attn.frfn.linear2.0.weight', 'layers.4.residual_group.overlap_attn.frfn.linear2.0.bias', 'layers.4.residual_group.overlap_attn.frfn.partial_conv3.weight', 'layers.5.residual_group.overlap_attn.ast_weight', 'layers.5.residual_group.overlap_attn.relative_position_bias_table', 'layers.5.residual_group.overlap_attn.frfn.linear1.0.weight', 'layers.5.residual_group.overlap_attn.frfn.linear1.0.bias', 'layers.5.residual_group.overlap_attn.frfn.dwconv.0.weight', 'layers.5.residual_group.overlap_attn.frfn.dwconv.0.bias', 'layers.5.residual_group.overlap_attn.frfn.linear2.0.weight', 'layers.5.residual_group.overlap_attn.frfn.linear2.0.bias', 'layers.5.residual_group.overlap_attn.frfn.partial_conv3.weight'], unexpected_keys=['layers.0.residual_group.overlap_attn.mlp.fc1.weight', 'layers.0.residual_group.overlap_attn.mlp.fc1.bias', 'layers.0.residual_group.overlap_attn.mlp.fc2.weight', 'layers.0.residual_group.overlap_attn.mlp.fc2.bias', 'layers.1.residual_group.overlap_attn.mlp.fc1.weight', 'layers.1.residual_group.overlap_attn.mlp.fc1.bias', 'layers.1.residual_group.overlap_attn.mlp.fc2.weight', 'layers.1.residual_group.overlap_attn.mlp.fc2.bias', 'layers.2.residual_group.overlap_attn.mlp.fc1.weight', 'layers.2.residual_group.overlap_attn.mlp.fc1.bias', 'layers.2.residual_group.overlap_attn.mlp.fc2.weight', 'layers.2.residual_group ...
# _IncompatibleKeys(missing_keys=['relative_position_index_OCA', 'layers.0.residual_group.overlap_attn.ast_weight', 'layers.0.residual_group.overlap_attn.relative_position_bias_table', 'layers.0.residual_group.overlap_attn.frfn.linear1.0.weight', 'layers.0.residual_group.overlap_attn.frfn.linear1.0.bias', 'layers.0.residual_group.overlap_attn.frfn.dwconv.0.weight', 'layers.0.residual_group.overlap_attn.frfn.dwconv.0.bias', 'layers.0.residual_group.overlap_attn.frfn.linear2.0.weight', 'layers.0.residual_group.overlap_attn.frfn.linear2.0.bias', 'layers.0.residual_group.overlap_attn.frfn.partial_conv3.weight', 'layers.1.residual_group.overlap_attn.ast_weight', 'layers.1.residual_group.overlap_attn.relative_position_bias_table', 'layers.1.residual_group.overlap_attn.frfn.linear1.0.weight', 'layers.1.residual_group.overlap_attn.frfn.linear1.0.bias', 'layers.1.residual_group.overlap_attn.frfn.dwconv.0.weight', 'layers.1.residual_group.overlap_attn.frfn.dwconv.0.bias', 'layers.1.residual_group.overlap_attn.frfn.linear2.0.weight', 'layers.1.residual_group.overlap_attn.frfn.linear2.0.bias', 'layers.1.residual_group.overlap_attn.frfn.partial_conv3.weight', 'layers.2.residual_group.overlap_attn.ast_weight', 'layers.2.residual_group.overlap_attn.relative_position_bias_table', 'layers.2.residual_group.overlap_attn.frfn.linear1.0.weight', 'layers.2.residual_group.overlap_attn.frfn.linear1.0.bias', 'layers.2.residual_group.overlap_attn.frfn.dwconv.0.weight', 'layers.2.residual_group.overlap_attn.frfn.dwconv.0.bias', 'layers.2.residual_group.overlap_attn.frfn.linear2.0.weight', 'layers.2.residual_group.overlap_attn.frfn.linear2.0.bias', 'layers.2.residual_group.overlap_attn.frfn.partial_conv3.weight', 'layers.3.residual_group.overlap_attn.ast_weight', 'layers.3.residual_group.overlap_attn.relative_position_bias_table', 'layers.3.residual_group.overlap_attn.frfn.linear1.0.weight', 'layers.3.residual_group.overlap_attn.frfn.linear1.0.bias', 'layers.3.residual_group.overlap_attn.frfn.dwconv.0.weight', 'layers.3.residual_group.overlap_attn.frfn.dwconv.0.bias', 'layers.3.residual_group.overlap_attn.frfn.linear2.0.weight', 'layers.3.residual_group.overlap_attn.frfn.linear2.0.bias', 'layers.3.residual_group.overlap_attn.frfn.partial_conv3.weight', 'layers.4.residual_group.overlap_attn.ast_weight', 'layers.4.residual_group.overlap_attn.relative_position_bias_table', 'layers.4.residual_group.overlap_attn.frfn.linear1.0.weight', 'layers.4.residual_group.overlap_attn.frfn.linear1.0.bias', 'layers.4.residual_group.overlap_attn.frfn.dwconv.0.weight', 'layers.4.residual_group.overlap_attn.frfn.dwconv.0.bias', 'layers.4.residual_group.overlap_attn.frfn.linear2.0.weight', 'layers.4.residual_group.overlap_attn.frfn.linear2.0.bias', 'layers.4.residual_group.overlap_attn.frfn.partial_conv3.weight', 'layers.5.residual_group.overlap_attn.ast_weight', 'layers.5.residual_group.overlap_attn.relative_position_bias_table', 'layers.5.residual_group.overlap_attn.frfn.linear1.0.weight', 'layers.5.residual_group.overlap_attn.frfn.linear1.0.bias', 'layers.5.residual_group.overlap_attn.frfn.dwconv.0.weight', 'layers.5.residual_group.overlap_attn.frfn.dwconv.0.bias', 'layers.5.residual_group.overlap_attn.frfn.linear2.0.weight', 'layers.5.residual_group.overlap_attn.frfn.linear2.0.bias', 'layers.5.residual_group.overlap_attn.frfn.partial_conv3.weight'], unexpected_keys=['layers.0.residual_group.overlap_attn.mlp.fc1.weight', 'layers.0.residual_group.overlap_attn.mlp.fc1.bias', 'layers.0.residual_group.overlap_attn.mlp.fc2.weight', 'layers.0.residual_group.overlap_attn.mlp.fc2.bias', 'layers.1.residual_group.overlap_attn.mlp.fc1.weight', 'layers.1.residual_group.overlap_attn.mlp.fc1.bias', 'layers.1.residual_group.overlap_attn.mlp.fc2.weight', 'layers.1.residual_group.overlap_attn.mlp.fc2.bias', 'layers.2.residual_group.overlap_attn.mlp.fc1.weight', 'layers.2.residual_group.overlap_attn.mlp.fc1.bias', 'layers.2.residual_group.overlap_attn.mlp.fc2.weight', 'layers.2.residual_group ...
